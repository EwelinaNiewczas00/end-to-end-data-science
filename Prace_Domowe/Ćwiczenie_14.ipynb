# %%
from sqlalchemy import create_engine, Column, Integer, String
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker
# Definicja modelu (raz, w jednym miejscu)
Base = declarative_base()
class User(Base):
    __tablename__ = 'users'
    id = Column(Integer, primary_key=True)
    name = Column(String(100))
    email = Column(String(100), unique=True)
    age = Column(Integer)
    def __repr__(self):
        return f"<User(name='{self.name}', email='{self.email}', age={self.age})>"
# Połączenie z bazą
engine = create_engine('postgresql://user:password@localhost/mydb')
Session = sessionmaker(bind=engine)
session = Session()
# Tworzenie rekordu - jak tworzenie obiektu!
new_user = User(name="Jan Kowalski", email="jan@example.com", age=30)
session.add(new_user)
session.commit()
# Pobieranie danych - czytelne zapytania
users = session.query(User).filter(User.age > 25).all()
# Zalety: typowanie, autocomplete, łatwe testy, przejrzystość
# Out:
# /var/folders/yj/jl4l61bx379272hbr8ldy_bc0000gn/T/ipykernel_54063/3668903630.py:5: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# File ~/PycharmProjects/Bootcamp2/.venv/lib/python3.14/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# ...
