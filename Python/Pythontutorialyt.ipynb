# %%
name = "Bro"
age = 25
gpa = 3.1
is_student = True

print(type(name))
print(type(age))
print(type(gpa))
print(type(is_student))

gpa = int(gpa)
print(type(gpa))
print(gpa)
age =float(age)
print(age)
age = str(age)
print(age)

name =bool(name)
print(name)
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'int'>
# 3
# 25.0
# 25.0
# True

# %% [markdown]
# 12 godzinny tutorial - https://www.youtube.com/watch?v=ix9cRaBkVe0

# %%
name = input("What is your name?: ")
print(f"hello {name}!")
age = int(input(" Ile masz lat?: "))

age = age + 1

print(f"masz {age} lat!")
# Out:
# hello Ewelina!
# masz 26 lat!

# %%
dl = float(input("podaj dlugosc: "))
sz = float(input("podaj szerokosc: "))
area = dl * sz

print(f"area ma wymiar {area} cm😂")
# Out:
# area ma wymiar 9.0 cm😂

# %%
produkt = input("Jaki chcesz produkt: ")
cena = float(input("Jaka jest cena?: "))
ilosc = int(input("Ile chcesz sztuk: "))
total = cena * ilosc

print(total)
print(f"Ty kupiłeś {ilosc} sztuk {produkt} za {total} zł")
# Out:
# 39.830000000000005
# Ty kupiłeś 7 sztuk mandarynki za 39.830000000000005 zł

# %% [markdown]
# Jakas gra : MADLIBS GAME
# word game story
