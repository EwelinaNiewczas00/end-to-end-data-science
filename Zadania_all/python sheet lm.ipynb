# %% [markdown]
# # 🚀 Python & Data Science - Kompletny Cheat Sheet
#
# Poniżej znajdziesz kompletne zestawienie funkcji i metod, z podziałem na logiczne kategorie. Kliknij w wybraną sekcję, aby ją rozwinąć.
#
# <details>
# <summary><b>1. Podstawy Pythona: Zmienne, Typy i Operatory</b></summary>
#
# W Pythonie typowanie jest dynamiczne, typ zmiennej jest określany automatycznie na podstawie przypisanej wartości [8].
# - **Podstawowe typy:** `int` (liczby całkowite), `float` (zmiennoprzecinkowe), `str` (tekst), `bool` (logiczne `True`/`False`) [9-11].
# - **Konwersje typów:** `int(x)`, `float(x)`, `str(x)`, `bool(x)` `*[Zewnętrzne]*` [12].
#
# **Operatory matematyczne:**
# - `+`, `-`, `*` (mnożenie), `/` (dzielenie zwracające float) [13, 14].
# - `//` (dzielenie całkowite bez reszty) [14].
# - `%` (modulo - reszta z dzielenia) [14].
# - `**` (potęgowanie, np. `x ** 0.5` to pierwiastek) [15].
#
# **Operatory logiczne i porównania:**
# - `>`, `<`, `>=`, `<=`, `==` (równe), `!=` (różne) [15].
# - `and` (i), `or` (lub), `not` (negacja) [16].
#
# **Formatowanie tekstu (f-strings):**
# ```python
# model = "XGBoost"
# wynik = 0.9543
# ilosc = 1500
# # :.2f - dwa miejsca po przecinku, :.2% - procenty, :, - separator tysięcy [17]
# print(f"Model: {model}, Wynik: {wynik:.2%}, Próbki: {ilosc:,}")
# Listy (list) - uporządkowane, modyfikowalne
# :
# lista = [9, 19, 20]
# lista.append(40)         # Dodaje element na koniec [21]
# lista.extend([22, 23])   # Rozszerza listę o inną kolekcję [24]
# lista.insert(1, 15)      # Wstawia wartość na konkretny indeks [24]
# lista.remove(20)         # Usuwa pierwsze wystąpienie wartości [25]
# lista.pop(0)             # Usuwa i zwraca element z indeksu [25]
# lista.clear()            # Czyści całą listę [26]
# lista.sort(reverse=True) # Sortuje listę w miejscu (malejąco) [27]
# # Wycinanie (slicing): lista[start:stop:krok] np. lista[::-1] (odwraca listę) [28]
# Stringi (str) - niemutowalne sekwencje znaków
# :
# tekst = "  Data Science  "
# tekst.strip()            # Usuwa białe znaki (spacje) z brzegów [30]
# tekst.lower() / .upper() # Małe / duże litery [30]
# tekst.replace(" ", "_")  # Podmiana fragmentów tekstu [30]
# tekst.split(",")         # Dzieli tekst na listę według separatora [31]
# ", ".join(["A", "B"])    # Łączy listę w string [32]
# tekst.startswith("Da")   # Sprawdza czy zaczyna się od "Da" [33]
# # *[Zewnętrzne]* Zfill: tekst.zfill(5) - wypełnia zerami od lewej
# Słowniki (dict) - pary klucz-wartość
# :
# d = {'a': 1, 'b': 2}
# d.get('c', 0)            # Pobiera wartość, jeśli brak klucza zwraca 0 (bezpieczne) [35]
# d.keys()                 # Zwraca listę kluczy [36]
# d.values()               # Zwraca listę wartości [36]
# d.items()                # Zwraca pary (klucz, wartość) - idealne do iteracji [37]
# d.update({'c': 3})       # Aktualizuje/dodaje wiele kluczy naraz [38]
# d.setdefault('d', 4)     # Dodaje klucz z wartością domyślną jeśli nie istnieje [39]
# Zbiory (set) - unikalne, nieuporządkowane elementy (bardzo szybkie)
# :
# z = {1, 2, 3}            # Z pustym zbiorem używaj set() a nie {} [41]
# z.add(4)                 # Dodanie elementu [42]
# z1 | z2                  # Suma zbiorów (.union) [43]
# z1 & z2                  # Przecięcie/wspólne (.intersection) [43]
# z1 - z2                  # Różnica (.difference) [44]
# z1 ^ z2                  # Różnica symetryczna (.symmetric_difference) [44]
# Krotki (tuple) - uporządkowane, ale niemutowalne (tylko do odczytu)
# :
# krotka = (1, 2, 3)
# x, y, z = krotka         # Unpacking (rozpakowywanie) do zmiennych [46]
# krotka.count(2)          # Liczy wystąpienia wartości [47]
# krotka.index(3)          # Znajduje indeks wartości [47]
# Instrukcje warunkowe
# :
# if warunek1:
#     pass
# elif warunek2:
#     pass
# else:
#     pass
# Pętle (for, while)
# :
# for i in range(0, 10, 2):     # Generuje sekwencję (start, stop, krok) [51]
# for i, val in enumerate(lst): # Iteracja z jednoczesnym dostępem do indeksu [52]
# for a, b in zip(lst1, lst2):  # *[Zewnętrzne]* Iteracja po wielu listach naraz
# while warunek:                # Wykonywana dopóki warunek jest True [49]
#     break                     # Natychmiastowe wyjście z pętli [53]
#     continue                  # Pomija iterację i przechodzi do kolejnej [54]
# Comprehensions (Najszybsze metody tworzenia kolekcji)
# :
# # List Comprehension [57]
# [x**2 for x in lista if x > 0]
# # Dictionary Comprehension [58]
# {klucz: wartosc for klucz, wartosc in zip(klucze, wartosci)}
# # Set Comprehension [59]
# {x.upper() for x in lista}
# Funkcje tradycyjne
# :
# def funkcja(arg1, arg2="domyślna"): # argument opcjonalny z wartością domyślną [61]
#     """Docstring opisujący co robi funkcja.""" [62]
#     return wynik1, wynik2 # Można zwracać wiele wartości jako Tuple [63]
# Funkcje Lambda (jednolinijkowe, anonimowe)
# :
# f = lambda x, y: x + y [65]
# # Przydatne przy sortowaniu:
# sorted(lista_krotek, key=lambda x: x[66], reverse=True) [67]
# Operacje funkcyjne (Map i Filter)
# :
# list(map(lambda x: x*2, lista))      # Aplikuje funkcję do każdego elementu [68]
# list(filter(lambda x: x>0, lista))   # Wyciąga tylko te elementy, gdzie lambda zwraca True [68]
# Dodatkowe przydatne funkcje [Zewnętrzne]:
# isinstance(zmienna, int) # Sprawdza czy zmienna jest danego typu
# try: ... except Exception as e: ... finally: ... # Obsługa błędów i wyjątków
# with open('plik.txt', 'r') as f: f.read() # Bezpieczne wczytywanie plików tekstowych
# NumPy oferuje do 100x szybsze operacje na danych, operując bezpośrednio na tablicach napisanych w C
# .
# Tworzenie tablic i właściwości
# :
# import numpy as np
# np.array([8, 66, 74])                # Z listy [70]
# np.zeros((3, 4))                   # Zera (wiersze, kolumny) [71]
# np.ones((2, 3))                    # Jedynki [71]
# np.full((2, 2), 7)                 # Wypełnione stałą wartością [71]
# np.arange(0, 10, 2)                # Odpowiednik range() [72]
# np.linspace(0, 1, 5)               # Określona liczba równoodległych punktów [72]
# np.random.randint(1, 100, size=10) # Tablica wartości losowych [72]
# arr.shape                          # Zwraca (wiersze, kolumny) [71]
# arr.ndim                           # Wymiarowość (1D, 2D) [71]
# Indeksowanie i Slicing
# : Uwaga: Slicing w NumPy zwraca WIDOK (zmiany wpływają na oryginał). Używaj .copy() jeśli chcesz zrobić twardą kopię
# .
# arr[wiersze, kolumny]              # Wycinanie macierzy 2D [77]
# arr[:, 3]                          # Wszystkie wiersze, 3-cia kolumna [78]
# arr[arr > 50]                      # Boolean indexing - filtrowanie warunkowe [79]
# Operacje na tablicach i statystyki
# : Nie używaj pętli! NumPy aplikuje to automatycznie do całej macierzy (Wektoryzacja i Broadcasting)
# .
# np.sqrt(arr) / np.square(arr)      # Pierwiastek, Kwadrat [80]
# np.abs(arr) / np.clip(arr, 10, 20) # Moduł, limitowanie wartości [81, 84]
# np.mean(arr, axis=0)               # Średnia wzdłuż kolumn (redukuje wiersze) [85]
# np.sum(arr, axis=1)                # Suma wzdłuż wierszy (redukuje kolumny) [85]
# np.max(arr) / np.min(arr)          # Wartość maksymalna / minimalna [81]
# np.argmax(arr) / np.argmin(arr)    # Indeks maksymalnej / minimalnej wartości [85]
# Wczytywanie i inspekcja
# :
# import pandas as pd
# # Używaj parametru chunksize i usecols dla obniżenia zużycia RAM [87, 88]
# df = pd.read_csv('dane.csv', sep=';', usecols=['Col1', 'Col2']) [87]
# df.head(5)               # Zwraca pierwsze wiersze [86]
# df.info()                # Typy kolumn, błędy, zużycie pamięci [86]
# df.describe()            # Podstawowe statystyki opisowe dla danych numerycznych [86]
# df.shape                 # Kształt DataFrame (wiersze, kolumny) [86]
# df.dtypes                # Typy danych [89]
# df.memory_usage(deep=True) # Analiza zużycia RAM [90]
# # *[Zewnętrzne]* df.value_counts() - Zlicza ilości unikalnych wartości w kolumnie
# Selekcja i Filtrowanie
# :
# df[['kol1', 'kol2']]                  # Zwraca wybrany DataFrame [91]
# df.loc[0:4, ['Name', 'Age']]          # Etykiety: start i stop SĄ WŁĄCZONE [92]
# df.iloc[0:5, [66, 74]]                  # Pozycje: stop NIE JEST WŁĄCZONY [92]
# df[(df['Age'] > 20) & (df['Sex'] == 'M')] # Standardowe filtrowanie [93]
# df.query("Age > 20 and Sex == 'M'")   # Składnia uproszczona, czytelniejsza [94]
# df.filter(regex='^Start')             # Filtrowanie kolumn po wzorcach nazw [95]
# Radzenie sobie z brakami (NaN)
# :
# df.isnull().sum()                     # Liczy ilość braków w kolumnach [96]
# df.dropna(subset=['Age'])             # Usuwa wiersze z NaN we wskazanych kolumnach [99]
# df.dropna(thresh=10, axis=1)          # Usuwa kolumny (axis=1) jeśli braków jest za dużo [99]
# df['Age'].fillna(df['Age'].median())  # Wypełnia braki stałą lub medianą [102]
# df['Date'].interpolate(method='time') # Oblicza braki matematycznie (najlepsze dla szeregów) [105]
# Grupowanie (Split-Apply-Combine)
# :
# # .agg() do agregacji (redukuje wiele wierszy do 1 wyniku) [107]
# df.groupby('Region').agg({'Sprzedaż': ['mean', 'sum'], 'Koszt': 'max'}) [107]
#
# # .transform() do kalkulacji zachowującej oryginalną wielkość DataFrame [108]
# # Przydatne przy standaryzacji, czy wypełnianiu braków statystykami z wewnątrz grupy [109, 110]
# df['Średnia_Grupy'] = df.groupby('Region')['Sprzedaż'].transform('mean') [108]
# Feature Engineering (Budowanie zmiennych)
# :
# # Kategoryzacja danych ciągłych w tzw. 'koszyki' [112, 113]
# pd.cut(df['Wiek'], bins=[23, 114, 115], labels=['Młody', 'Dorosły', 'Senior']) [112]
# pd.qcut(df['Dochód'], q=4) # Kwantyle (np. równe 4 grupy) [113]
#
# # Ekstrakcja danych z Daty (wymaga by kolumna była typu datetime) [116]
# df['Rok'] = df['Data'].dt.year [116]
# df['Miesiąc'] = df['Data'].dt.month [116]
# df['Dzień_tyg'] = df['Data'].dt.dayofweek [116]
# Modyfikacja i Łączenie Danych [Zewnętrzne]:
# # Podstawowe transformacje bazy:
# df.rename(columns={'Stara': 'Nowa'}, inplace=True) # Zmiana nazwy kolumny
# df.drop(columns=['Niepotrzebna'], inplace=True)    # Usunięcie całej kolumny
# df.sort_values(by='Wiek', ascending=False)         # Sortowanie wierszy
#
# # Łączenie wielu tabel:
# pd.concat([df1, df2], axis=0)                # Łączenie bazy jedna pod drugą (Unia wierszy)
# pd.merge(df1, df2, on='ID', how='left')      # Łączenie relacyjne jak w SQL (JOIN tabel)
# Narzędzia Machine Learningowe (Wstęp z Scikit-learn) [Zewnętrzne]:
# from sklearn.model_selection import train_test_split
# # Podział na zbiór uczący i testowy
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
